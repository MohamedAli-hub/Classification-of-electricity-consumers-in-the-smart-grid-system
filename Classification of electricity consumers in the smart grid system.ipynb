# %%
#Importer les Bibliothéques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime 
import seaborn as sns

# %%
##Concaténation

# %%
file1=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_120.csv")
file2=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_121.csv")
file3=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_122.csv")
file4=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_123.csv")
file5=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_124.csv")
file6=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_125.csv")
file7=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_126.csv")
file8=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_127.csv")
file9=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_128.csv")
file10=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_129.csv")
file11=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_130.csv")
file12=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_131.csv")
file13=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_132.csv")
file14=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_133.csv")
file15=pd.read_csv(r"C:\Users\miste\LCL-June2015v2_134.csv")

# %%
file = pd.concat([file1,file2,file3,file4,file5,file6,file7,file8,file9,file10,file11,file12,file13,file14,file15],ignore_index=True)

# %%
file.head(10)
# Out:
#        LCLid stdorToU                     DateTime KWH/hh (per half hour)
# 0  MAC005007      Std  2012-07-09 02:30:00.0000000                   0.04
# 1  MAC005007      Std  2012-07-09 03:00:00.0000000                  0.042
# 2  MAC005007      Std  2012-07-09 03:30:00.0000000                  0.039
# 3  MAC005007      Std  2012-07-09 04:00:00.0000000                  0.028
# 4  MAC005007      Std  2012-07-09 04:30:00.0000000                  0.032
# 5  MAC005007      Std  2012-07-09 05:00:00.0000000                  0.043
# 6  MAC005007      Std  2012-07-09 05:30:00.0000000                   0.04
# 7  MAC005007      Std  2012-07-09 06:00:00.0000000                  0.029
# 8  MAC005007      Std  2012-07-09 06:30:00.0000000                   0.03
# 9  MAC005007      Std  2012-07-09 07:00:00.0000000                  0.175

# %%
file.tail(10)
# Out:
#               LCLid stdorToU                     DateTime  \
# 14999990  MAC000146      ToU  2012-08-16 21:00:00.0000000
# 14999991  MAC000146      ToU  2012-08-16 21:30:00.0000000
# 14999992  MAC000146      ToU  2012-08-16 22:00:00.0000000
# 14999993  MAC000146      ToU  2012-08-16 22:30:00.0000000
# 14999994  MAC000146      ToU  2012-08-16 23:00:00.0000000
# 14999995  MAC000146      ToU  2012-08-16 23:30:00.0000000
# 14999996  MAC000146      ToU  2012-08-17 00:00:00.0000000
# 14999997  MAC000146      ToU  2012-08-17 00:30:00.0000000
# 14999998  MAC000146      ToU  2012-08-17 01:00:00.0000000
# 14999999  MAC000146      ToU  2012-08-17 01:30:00.0000000
#
#          KWH/hh (per half hour)
# 14999990                  0.188
# 14999991                  0.137
# 14999992                  0.116
# 14999993                  0.138
# 14999994                  0.197
# 14999995                  0.155
# 14999996                  0.125
# 14999997                  0.069
# ...

# %%
df = pd.DataFrame(file)

# %%
column = df.iloc[:, 3]
df = df.drop(df[column == "Null"].index)
df = df.drop('stdorToU',axis=1)

# %%
mesure = len(df)
print("nombre de mesure est ",mesure)
# Out:
# nombre de mesure est  14999541

# %%
df.head(10)
# Out:
#        LCLid                     DateTime KWH/hh (per half hour)
# 0  MAC005007  2012-07-09 02:30:00.0000000                   0.04
# 1  MAC005007  2012-07-09 03:00:00.0000000                  0.042
# 2  MAC005007  2012-07-09 03:30:00.0000000                  0.039
# 3  MAC005007  2012-07-09 04:00:00.0000000                  0.028
# 4  MAC005007  2012-07-09 04:30:00.0000000                  0.032
# 5  MAC005007  2012-07-09 05:00:00.0000000                  0.043
# 6  MAC005007  2012-07-09 05:30:00.0000000                   0.04
# 7  MAC005007  2012-07-09 06:00:00.0000000                  0.029
# 8  MAC005007  2012-07-09 06:30:00.0000000                   0.03
# 9  MAC005007  2012-07-09 07:00:00.0000000                  0.175

# %%
print("Le nombre de compteurs:")
print(file["LCLid"].value_counts())
# Out:
# Le nombre de compteurs:
# MAC000017    39114
# MAC000015    39089
# MAC000031    39059
# MAC000048    39028
# MAC000046    39025
#              ...
# MAC005062     9726
# MAC005559        1
# MAC005556        1
# MAC005560        1
# MAC005563        1
# Name: LCLid, Length: 461, dtype: int64

# %%
file.columns = ['LCLid', 'stdorToU', 'DateTime', 'consommation']

# %%
print(file)
# Out:
#               LCLid stdorToU                     DateTime consommation
# 0         MAC005007      Std  2012-07-09 02:30:00.0000000        0.04
# 1         MAC005007      Std  2012-07-09 03:00:00.0000000       0.042
# 2         MAC005007      Std  2012-07-09 03:30:00.0000000       0.039
# 3         MAC005007      Std  2012-07-09 04:00:00.0000000       0.028
# 4         MAC005007      Std  2012-07-09 04:30:00.0000000       0.032
# ...             ...      ...                          ...          ...
# 14999995  MAC000146      ToU  2012-08-16 23:30:00.0000000       0.155
# 14999996  MAC000146      ToU  2012-08-17 00:00:00.0000000       0.125
# 14999997  MAC000146      ToU  2012-08-17 00:30:00.0000000       0.069
# 14999998  MAC000146      ToU  2012-08-17 01:00:00.0000000       0.101
# 14999999  MAC000146      ToU  2012-08-17 01:30:00.0000000       0.071
#
# [15000000 rows x 4 columns]

# %%
df = pd.DataFrame(file)
for i in range(15000000):
    if(df.consommation[i] == 'Null'):
        df.consommation[i] = '0'

# %%
df.consommation= pd.to_numeric(df.consommation)

# %%
print(df["consommation"].max())
# Out:
# 9.1409998

# %%
print(df["consommation"].min())
# Out:
# 0.0

# %%
print(df["consommation"].mean())
# Out:
# 0.2249953462606649

# %%
print(df["consommation"].sum())
# Out:
# 3374930.193909198

# %%
df0=df.groupby('LCLid').agg({'consommation': ['sum', 'min', 'max','mean']})

# %%
df0
# Out:
#            consommation
#                     sum  min    max      mean
# LCLid
# MAC000005   2911.808000  0.0  1.979  0.095385
# MAC000014   3132.670999  0.0  2.132  0.130332
# MAC000015   8957.714000  0.0  2.613  0.229162
# MAC000017   5202.072001  0.0  2.331  0.132998
# MAC000031  16295.187997  0.0  4.247  0.417194
# ...                 ...  ...    ...       ...
# MAC005561   4193.402000  0.0  1.886  0.151995
# MAC005562   6910.988999  0.0  1.879  0.218012
# MAC005563      0.000000  0.0  0.000  0.000000
# MAC005566   8946.788998  0.0  3.936  0.363085
# MAC005567   2268.484999  0.0  1.528  0.108556
#
# [461 rows x 4 columns]

# %%
df["DateTime"] = pd.to_datetime(df['DateTime'])
df["DateTime"]
# Out:
# 0          2012-07-09 02:30:00
# 1          2012-07-09 03:00:00
# 2          2012-07-09 03:30:00
# 3          2012-07-09 04:00:00
# 4          2012-07-09 04:30:00
#                    ...
# 14999995   2012-08-16 23:30:00
# 14999996   2012-08-17 00:00:00
# 14999997   2012-08-17 00:30:00
# 14999998   2012-08-17 01:00:00
# 14999999   2012-08-17 01:30:00
# Name: DateTime, Length: 15000000, dtype: datetime64[ns]

# %%
df["weekday"] = pd.to_datetime(df.DateTime).dt.day_name()
df["weekday"]
# Out:
# 0             Monday
# 1             Monday
# 2             Monday
# 3             Monday
# 4             Monday
#               ...
# 14999995    Thursday
# 14999996      Friday
# 14999997      Friday
# 14999998      Friday
# 14999999      Friday
# Name: weekday, Length: 15000000, dtype: object

# %%
df["month"]=pd.to_datetime(df.DateTime).dt.month_name()
df["month"]
# Out:
# 0             July
# 1             July
# 2             July
# 3             July
# 4             July
#              ...
# 14999995    August
# 14999996    August
# 14999997    August
# 14999998    August
# 14999999    August
# Name: month, Length: 15000000, dtype: object

# %%
df["weekday"].replace({"Sunday": "Weekend", "Saturday": "Weekend"}, inplace=True)

# %%
df1=df.groupby(['LCLid','weekday']).agg({'consommation': ['mean']}).unstack()

# %%
df1
# Out:
#           consommation
#                   mean
# weekday         Friday    Monday  Thursday   Tuesday Wednesday   Weekend
# LCLid
# MAC000005     0.096364  0.104157  0.089285  0.093749  0.093253  0.095452
# MAC000014     0.122962  0.127625  0.133138  0.138966  0.124083  0.132754
# MAC000015     0.279244  0.206488  0.224172  0.213075  0.245149  0.217960
# MAC000017     0.137118  0.129727  0.131517  0.118622  0.139714  0.137141
# MAC000031     0.353874  0.379685  0.363709  0.397497  0.452044  0.486887
# ...                ...       ...       ...       ...       ...       ...
# MAC005561     0.143070  0.154062  0.155568  0.157067  0.153036  0.150564
# MAC005562     0.211326  0.216657  0.213150  0.223063  0.218843  0.221510
# MAC005563          NaN       NaN       NaN       NaN  0.000000       NaN
# MAC005566     0.370457  0.368846  0.357546  0.376491  0.356384  0.356017
# MAC005567     0.118291  0.111119  0.098492  0.106132  0.103454  0.111280
#
# [461 rows x 6 columns]

# %%
df2=df.groupby(['LCLid','month',]).agg({'consommation': ['mean']}).unstack()
df2
# Out:
#           consommation                                                    \
#                   mean
# month            April    August  December  February   January      July
# LCLid
# MAC000005     0.091192  0.081748  0.120143  0.111776  0.115403  0.078975
# MAC000014     0.121143  0.109840  0.148667  0.142179  0.149668  0.084555
# MAC000015     0.172663  0.187595  0.261687  0.284527  0.278502  0.183657
# MAC000017     0.126987  0.123031  0.138492  0.149389  0.166431  0.130255
# MAC000031     0.350321  0.178974  0.454380  0.494584  0.550488  0.340201
# ...                ...       ...       ...       ...       ...       ...
# MAC005561     0.143615  0.091422  0.199011  0.210832  0.192797  0.114964
# MAC005562     0.260709  0.142179  0.262332  0.273900  0.262678  0.168384
# MAC005563          NaN       NaN  0.000000       NaN       NaN       NaN
# MAC005566     0.356997  0.607306  0.126849  0.185331  0.110057  0.854140
# ...

# %%
df["weekdaynumber"] = pd.to_datetime(df.DateTime).dt.dayofweek
df["weekdaynumber"]
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#            ..
# 14999995    3
# 14999996    4
# 14999997    4
# 14999998    4
# 14999999    4
# Name: weekdaynumber, Length: 15000000, dtype: int64

# %%
df["monthnumber"]=pd.to_datetime(df.DateTime).dt.month
df["monthnumber"]
# Out:
# 0           7
# 1           7
# 2           7
# 3           7
# 4           7
#            ..
# 14999995    8
# 14999996    8
# 14999997    8
# 14999998    8
# 14999999    8
# Name: monthnumber, Length: 15000000, dtype: int64

# %%
df["season"]= (df["monthnumber"]%12 // 3 + 1)
df["season"]
# Out:
# 0           3
# 1           3
# 2           3
# 3           3
# 4           3
#            ..
# 14999995    3
# 14999996    3
# 14999997    3
# 14999998    3
# 14999999    3
# Name: season, Length: 15000000, dtype: int64

# %%
df['season'] = 'season ' + df['season'].astype(str)
df['season']
# Out:
# 0           season season 3
# 1           season season 3
# 2           season season 3
# 3           season season 3
# 4           season season 3
#                  ...
# 14999995    season season 3
# 14999996    season season 3
# 14999997    season season 3
# 14999998    season season 3
# 14999999    season season 3
# Name: season, Length: 15000000, dtype: object

# %% [markdown]
# df['periode'] = 'periode ' + df['periode'].astype(str)

# %%
df["periode"]= df["DateTime"].dt.hour %24 //8 + 1
# Out:
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#            ..
# 14999995    3
# 14999996    1
# 14999997    1
# 14999998    1
# 14999999    1
# Name: periode, Length: 15000000, dtype: int64

# %%
df3=df.groupby(['LCLid','season']).agg({'consommation': ['mean']}).unstack()
df3
# Out:
#           consommation
#                   mean
# season        season 1  season 2  season 3  season 4
# LCLid
# MAC000005     0.115930  0.093347  0.077928  0.093711
# MAC000014     0.147020  0.115403  0.101427  0.137932
# MAC000015     0.274848  0.212183  0.186842  0.222772
# MAC000017     0.151782  0.119833  0.120920  0.131224
# MAC000031     0.501116  0.413466  0.293717  0.424273
# ...                ...       ...       ...       ...
# MAC005561     0.200493  0.142463  0.108924  0.137740
# MAC005562     0.266006  0.226883  0.159673  0.223442
# MAC005563     0.000000       NaN       NaN       NaN
# MAC005566     0.139007  0.293534  0.656380  0.493330
# MAC005567     0.113664  0.095749  0.108505  0.112563
#
# [461 rows x 4 columns]

# %%
df4=df.groupby(['LCLid','periode']).agg({'consommation': ['mean']}).unstack()

# %%
df4
# Out:
#           consommation
#                   mean
# periode      periode 1 periode 2 periode 3
# LCLid
# MAC000005     0.044894  0.091721  0.149583
# MAC000014     0.080308  0.187521  0.123193
# MAC000015     0.127207  0.268949  0.291527
# MAC000017     0.070333  0.138637  0.190092
# MAC000031     0.205624  0.489440  0.556824
# ...                ...       ...       ...
# MAC005561     0.075379  0.185921  0.194765
# MAC005562     0.112731  0.252142  0.289393
# MAC005563          NaN  0.000000       NaN
# MAC005566     0.250454  0.429897  0.409116
# MAC005567     0.065945  0.106982  0.152811
#
# [461 rows x 3 columns]

# %%
regrouper_dataframes = pd.concat([df0, df1,df2,df3,df4], axis=1)
df_finale= regrouper_dataframes.reset_index()
df_finale.columns = ['CompteurID','mean', 'min', 'max', 'sum','Friday','Monday','Thursday','Tuesday','Wednesday','Weekend','April','August','December','February','January','July','June','March','May','November','October','September','season 1','season 2','season 3','season 4','periode1','periode2','periode3']

# %%
df_finale
# Out:
#     CompteurID          mean  min    max       sum    Friday    Monday  \
# 0    MAC000005   2911.808000  0.0  1.979  0.095385  0.096364  0.104157
# 1    MAC000014   3132.670999  0.0  2.132  0.130332  0.122962  0.127625
# 2    MAC000015   8957.714000  0.0  2.613  0.229162  0.279244  0.206488
# 3    MAC000017   5202.072001  0.0  2.331  0.132998  0.137118  0.129727
# 4    MAC000031  16295.187997  0.0  4.247  0.417194  0.353874  0.379685
# ..         ...           ...  ...    ...       ...       ...       ...
# 456  MAC005561   4193.402000  0.0  1.886  0.151995  0.143070  0.154062
# 457  MAC005562   6910.988999  0.0  1.879  0.218012  0.211326  0.216657
# 458  MAC005563      0.000000  0.0  0.000  0.000000       NaN       NaN
# 459  MAC005566   8946.788998  0.0  3.936  0.363085  0.370457  0.368846
# 460  MAC005567   2268.484999  0.0  1.528  0.108556  0.118291  0.111119
#
#      Thursday   Tuesday  Wednesday  ...  November   October  September  \
# ...

# %%
#Recherche du K optimal et Classification Non Supervisé K_means

# %%
from sklearn import cluster
from sklearn import metrics
from sklearn import preprocessing

# %%
df_finale.drop_duplicates(inplace=True)
df_finale.dropna(inplace=True)

# %%
X =df_finale.iloc[:, [1,10]].values

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    # inertia method returns wcss for that model
    wcss.append(kmeans.inertia_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
plt.figure(figsize=(10,5))
sns.lineplot(range(1, 11), wcss,marker='o',color='red')
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
kmeans = KMeans(n_clusters =3,init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %%
#Classification Non Supervisé K_means

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], color = 'yellow', label = 'Cluster 1',s=50)
sns.scatterplot(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], color = 'blue', label = 'Cluster 2',s=50)
sns.scatterplot(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], color = 'green', label = 'Cluster 3',s=50)
#sns.scatterplot(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], color = 'grey', label = 'Cluster 4',s=50)
#sns.scatterplot(X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], color = 'orange', label = 'Cluster 5',s=50)
sns.scatterplot(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], color = 'red', 
                label = 'Centroids',s=300,marker=',')
plt.grid(False)
plt.title('Clusters of customers')
plt.xlabel('consommation moyenne ')
plt.ylabel('consommation dans le weekend ')
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...
